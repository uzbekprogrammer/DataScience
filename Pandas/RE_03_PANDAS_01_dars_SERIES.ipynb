# %% [markdown]
# <a href="https://colab.research.google.com/github/uzbekprogrammer/DataScience/blob/main/Pandas/RE_03_PANDAS_01_dars_SERIES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# ### 2.2 Pandas kutubxonasi bilan tanishuv

# %%
import pandas as pd
import numpy as np

# %%
from pandas import Series # series malumotlar tuzilmasi

# %%
obj=Series([4,5,6,-6.5])
obj

# %%
obj.values #qiymatlar

# %%
obj.index

# %%
obj[0]

# %%
obj2=Series([6,3,2,1], index=['a','b','c','d'])
obj2

# %%
obj2[['a','a','b']]
